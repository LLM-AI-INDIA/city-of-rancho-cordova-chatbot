# %%
# -------------------------------
# 1. Clone your GitHub repo
# -------------------------------

# !git clone --depth 1 https://github.com/LLM-AI-INDIA/city-of-rancho-cordova-chatbot.git
# %cd city-of-rancho-cordova-chatbot

# -------------------------------
# 2. Install requirements
# -------------------------------
# !pip install -r requirements.txt
# !pip install pyngrok

# -------------------------------
# 3. Set OpenAI API key (secure)
# -------------------------------
import getpass, os
os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

# -------------------------------
# 4. Set ngrok token
# -------------------------------
from pyngrok import ngrok
ngrok.set_auth_token("YOUR_NGROK_AUTH_TOKEN")

# Kill any previous ngrok process
import os, time
os.system("pkill -f ngrok")
time.sleep(3)

# -------------------------------
# 5. Start ngrok tunnel
# -------------------------------
public_url = ngrok.connect(8501)
print("🔥 Your Streamlit App is available at:", public_url)

# -------------------------------
# 6. Run Streamlit app
# -------------------------------
get_ipython().system_raw('streamlit run app.py --server.port 8501 &')

# Keep alive
while True:
    time.sleep(60)
